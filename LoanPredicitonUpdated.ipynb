# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
loan = pd.read_csv('trainLoan.csv')

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
loan.boxplot(column='ApplicantIncome',by='Gender')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
loan[loan['ApplicantIncome']>30000]
# Out:
#       Loan_ID Gender Married Dependents Education Self_Employed  \
# 155  LP001536   Male     Yes         3+  Graduate            No
# 171  LP001585    NaN     Yes         3+  Graduate            No
# 183  LP001637   Male     Yes          1  Graduate            No
# 185  LP001640   Male     Yes          0  Graduate           Yes
# 333  LP002101   Male     Yes          0  Graduate           NaN
# 409  LP002317   Male     Yes         3+  Graduate            No
# 443  LP002422   Male      No          1  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# 171            51763                0.0       700.0             300.0
# 183            33846                0.0       260.0             360.0
# 185            39147             4750.0       120.0             360.0
# 333            63337                0.0       490.0             180.0
# ...

# %%
loan['Self_Employed'].value_counts(dropna=False)
# Out:
# No     500
# Yes     82
# NaN     32
# Name: Self_Employed, dtype: int64

# %%
loan.at[333, 'Self_Employed'] ='No'

# %%
loan.at[171, 'Gender'] ='Male'

# %%
loan.boxplot(column='CoapplicantIncome',by='Gender')
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:57: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   return getattr(obj, method)(*args, **kwds)

# %%
loan[(loan['CoapplicantIncome']>15000)|(loan['ApplicantIncome']>30000)].plot(kind="scatter",x='ApplicantIncome',y='CoapplicantIncome')

# %%
loan.plot(kind='scatter',x='ApplicantIncome',y="CoapplicantIncome")

# %%
loan[(loan['CoapplicantIncome']>15000)|(loan['ApplicantIncome']>30000)]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 155  LP001536    Male     Yes         3+  Graduate            No
# 171  LP001585    Male     Yes         3+  Graduate            No
# 183  LP001637    Male     Yes          1  Graduate            No
# 185  LP001640    Male     Yes          0  Graduate           Yes
# 333  LP002101    Male     Yes          0  Graduate            No
# 402  LP002297    Male      No          0  Graduate            No
# 409  LP002317    Male     Yes         3+  Graduate            No
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 443  LP002422    Male      No          1  Graduate            No
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 155            39999                0.0       600.0             180.0
# ...

# %%
#many zero values are there in coapplicantincome how to deal with it???

# %%
loan.at[600, 'Credit_History'] ='1.0'

# %%
plt.hist(loan['ApplicantIncome'])
# Out:
# (array([ 533.,   59.,   15.,    0.,    4.,    0.,    1.,    1.,    0.,    1.]),
#  array([   150.,   8235.,  16320.,  24405.,  32490.,  40575.,  48660.,
#          56745.,  64830.,  72915.,  81000.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(loan['CoapplicantIncome'])
# Out:
# (array([ 561.,   46.,    3.,    0.,    2.,    0.,    0.,    0.,    1.,    1.]),
#  array([     0. ,   4166.7,   8333.4,  12500.1,  16666.8,  20833.5,
#          25000.2,  29166.9,  33333.6,  37500.3,  41667. ]),
#  <a list of 10 Patch objects>)

# %%
#0-5000(low)
#5000-10000(medium)
#10000-30000(high)
#30000+(vhigh)
#COAPPLICANTINCOME
#ApplicantIncome

# %%
loan['Dependents'].value_counts(dropna=False)
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               3
# Dependents           15
# Education             0
# Self_Employed        31
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan['Married'].value_counts()#Will do it later
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
loan['Gender'].value_counts()#i think we have to do it by knn imputation
# Out:
# Male      490
# Female    112
# Name: Gender, dtype: int64

# %%
sns.pairplot(loan[loan['Gender']=="Male"].dropna())

# %%
sns.pairplot(loan[loan['Gender']=="Female"].dropna())

# %%
#Lets do married column
loan['Married'].value_counts(dropna=False)
# Out:
# Yes    398
# No     213
# NaN      3
# Name: Married, dtype: int64

# %%
plt.hist(loan[loan['Married']=='No']['ApplicantIncome'])
# Out:
# (array([ 124.,   62.,   15.,    5.,    4.,    2.,    0.,    0.,    0.,    1.]),
#  array([   416. ,   4146.3,   7876.6,  11606.9,  15337.2,  19067.5,
#          22797.8,  26528.1,  30258.4,  33988.7,  37719. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(loan[loan['Married']=='Yes']['ApplicantIncome'])
# Out:
# (array([ 345.,   36.,   11.,    0.,    3.,    0.,    1.,    1.,    0.,    1.]),
#  array([   150.,   8235.,  16320.,  24405.,  32490.,  40575.,  48660.,
#          56745.,  64830.,  72915.,  81000.]),
#  <a list of 10 Patch objects>)

# %%
loan[loan['Married'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status
# 104             1.0         Urban           Y
# 228             1.0     Semiurban           Y
# 435             1.0     Semiurban           Y

# %%
loan[(loan['ApplicantIncome']>10000)&(loan['Gender']=='Female')]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 119  LP001422  Female      No          0      Graduate            No
# 146  LP001516  Female     Yes          2      Graduate            No
# 370  LP002194  Female      No          0      Graduate           Yes
# 435  LP002393  Female     NaN        NaN      Graduate            No
# 493  LP002582  Female      No          0  Not Graduate           Yes
# 509  LP002634  Female      No          1      Graduate            No
# 534  LP002731  Female      No          0  Not Graduate           Yes
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 604  LP002959  Female     Yes          1      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 54             11500                0.0       286.0             360.0
# ...

# %%
sns.countplot(loan['Married'])

# %%
sns.countplot(loan['Self_Employed'])

# %%
#those who are married they have max probablity that they are not self employed
loan.at[104, 'Married'] ='Yes'
loan.at[228, 'Married'] ='Yes'
loan.at[435,'Married']='No'

# %%
loan['Dependents'].value_counts(dropna=False)
# Out:
# 0      345
# 1      102
# 2      101
# 3+      51
# NaN     15
# Name: Dependents, dtype: int64

# %%
loan[loan['Dependents']=='3+']['Married'].value_counts()
# Out:
# Yes    44
# No      7
# Name: Married, dtype: int64

# %%
loan[loan['Dependents']=='2']['Married'].value_counts()
# Out:
# Yes    93
# No      8
# Name: Married, dtype: int64

# %%
loan[loan['Dependents']=='1']['Married'].value_counts()
# Out:
# Yes    79
# No     23
# Name: Married, dtype: int64

# %%
loan[loan['Dependents']=='0']['Married'].value_counts()
# Out:
# Yes    174
# No     171
# Name: Married, dtype: int64

# %%
loan[loan['Dependents'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 102  LP001350    Male     Yes        NaN      Graduate            No
# 104  LP001357    Male     Yes        NaN      Graduate            No
# 120  LP001426    Male     Yes        NaN      Graduate            No
# 226  LP001754    Male     Yes        NaN  Not Graduate           Yes
# 228  LP001760    Male     Yes        NaN      Graduate            No
# 293  LP001945  Female      No        NaN      Graduate            No
# 301  LP001972    Male     Yes        NaN  Not Graduate            No
# 332  LP002100    Male      No        NaN      Graduate            No
# 335  LP002106    Male     Yes        NaN      Graduate           Yes
# 346  LP002130    Male     Yes        NaN  Not Graduate            No
# 355  LP002144  Female      No        NaN      Graduate            No
# 435  LP002393  Female      No        NaN      Graduate            No
# 517  LP002682    Male     Yes        NaN  Not Graduate            No
# ...

# %%
loan['Education'].value_counts(dropna=False)
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
loan[loan['Gender']=='Female'].tail(10)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 556  LP002794  Female      No          0      Graduate            No
# 559  LP002804  Female     Yes          0      Graduate            No
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 568  LP002840  Female      No          0      Graduate            No
# 582  LP002894  Female     Yes          0      Graduate            No
# 587  LP002917  Female      No          0  Not Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 604  LP002959  Female     Yes          1      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 556             2667             1625.0        84.0             360.0
# ...

# %%
loan[loan['Gender']=='Female']['Dependents'].fillna("0",inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
loan.at[293, 'Dependents'] ='0'

# %%
loan.at[355, 'Dependents'] ='0'
loan.at[435, 'Dependents'] ='0'

# %%
loan.iloc[355]
# Out:
# Loan_ID              LP002144
# Gender                 Female
# Married                    No
# Dependents                  0
# Education            Graduate
# Self_Employed              No
# ApplicantIncome          3813
# CoapplicantIncome           0
# LoanAmount                116
# Loan_Amount_Term          180
# Credit_History              1
# Property_Area           Urban
# Loan_Status                 Y
# Name: 355, dtype: object

# %%
loan['Married'].value_counts()
# Out:
# Yes    400
# No     214
# Name: Married, dtype: int64

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               0
# Dependents           12
# Education             0
# Self_Employed        31
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan[loan['Self_Employed'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 95   LP001326    Male      No          0      Graduate           NaN
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 114  LP001398    Male      No          0      Graduate           NaN
# 158  LP001546    Male      No          0      Graduate           NaN
# 170  LP001581    Male     Yes          0  Not Graduate           NaN
# 218  LP001732    Male     Yes          2      Graduate           NaN
# 231  LP001768    Male     Yes          0      Graduate           NaN
# ...

# %%
loan[loan['Self_Employed']=='Yes']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 25   LP001066    Male     Yes          0      Graduate           Yes
# 32   LP001097    Male      No          1      Graduate           Yes
# 44   LP001136    Male     Yes          0  Not Graduate           Yes
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 62   LP001207    Male     Yes          0  Not Graduate           Yes
# 68   LP001238    Male     Yes         3+  Not Graduate           Yes
# 71   LP001245    Male     Yes          2  Not Graduate           Yes
# 74   LP001253    Male     Yes         3+      Graduate           Yes
# 77   LP001259    Male     Yes          1      Graduate           Yes
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 81   LP001266    Male     Yes          1      Graduate           Yes
# ...

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
sns.pairplot(loan.dropna(),hue='Self_Employed')

# %%
s = loan[['Self_Employed','Credit_History','Loan_Amount_Term']]

# %%
plt.hist(loan[loan['Self_Employed']=='Yes'].dropna()['Loan_Amount_Term'])
# Out:
# (array([  1.,   0.,   1.,   0.,   4.,   0.,   1.,   0.,   3.,  56.]),
#  array([  60.,   90.,  120.,  150.,  180.,  210.,  240.,  270.,  300.,
#          330.,  360.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(loan[loan['Self_Employed']=='No'].dropna()['Loan_Amount_Term'])
# Out:
# (array([   3.,    5.,    0.,   34.,    1.,    7.,    0.,  355.,    0.,   13.]),
#  array([  36. ,   80.4,  124.8,  169.2,  213.6,  258. ,  302.4,  346.8,
#          391.2,  435.6,  480. ]),
#  <a list of 10 Patch objects>)

# %%
#loanAmountterm above 400+(selfemployed==No)
loan[(loan['ApplicantIncome']>400)&(loan['CoapplicantIncome']>8000)]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9    LP001020    Male     Yes          1  Graduate            No
# 12   LP001028    Male     Yes          2  Graduate            No
# 122  LP001431  Female      No          0  Graduate            No
# 177  LP001610    Male     Yes         3+  Graduate            No
# 402  LP002297    Male      No          0  Graduate            No
# 417  LP002342    Male     Yes          2  Graduate           Yes
# 444  LP002424    Male     Yes          0  Graduate            No
# 581  LP002893    Male      No          0  Graduate            No
# 600  LP002949  Female      No         3+  Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 12              3073             8106.0       200.0             360.0
# 122             2137             8980.0       137.0             360.0
# ...

# %%
loan.at[600,'Self_Employed']='No'

# %%
loan[loan['Self_Employed']=='Yes'].head()
# Out:
#      Loan_ID Gender Married Dependents     Education Self_Employed  \
# 2   LP001005   Male     Yes          0      Graduate           Yes
# 5   LP001011   Male     Yes          2      Graduate           Yes
# 25  LP001066   Male     Yes          0      Graduate           Yes
# 32  LP001097   Male      No          1      Graduate           Yes
# 44  LP001136   Male     Yes          0  Not Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2              3000                0.0        66.0             360.0
# 5              5417             4196.0       267.0             360.0
# 25             9560                0.0       191.0             360.0
# 32             4692                0.0       106.0             360.0
# 44             4695                0.0        96.0               NaN
#
#     Credit_History Property_Area Loan_Status
# 2              1.0         Urban           Y
# 5              1.0         Urban           Y
# ...

# %%
loan[loan['Self_Employed']=='No'].head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 6  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
# 6             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
Gender=pd.crosstab(loan['Gender'],loan['Loan_Status'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
loan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               0
# Dependents           12
# Education             0
# Self_Employed        30
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan[loan['Credit_History'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 16   LP001034    Male      No          1  Not Graduate            No
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 42   LP001123    Male     Yes          0      Graduate            No
# 79   LP001264    Male     Yes         3+  Not Graduate           Yes
# 83   LP001273    Male     Yes          0      Graduate            No
# 86   LP001280    Male     Yes          2  Not Graduate            No
# 95   LP001326    Male      No          0      Graduate           NaN
# 117  LP001405    Male     Yes          1      Graduate            No
# 125  LP001443  Female      No          0      Graduate            No
# 129  LP001465    Male     Yes          0      Graduate            No
# 130  LP001469    Male      No          0      Graduate           Yes
# 156  LP001541    Male     Yes          1      Graduate            No
# ...

# %%
Gender=pd.crosstab(loan['Credit_History'],loan['Loan_Status'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
credit = loan['Credit_History']
count=0
for i in range(0,len(credit)):
    if loan['Credit_History'][i]==-10 and loan['Loan_Status'][i]=='N':
        loan['Credit_History'][i]=0
    if loan['Credit_History'][i]==-10 and loan['Loan_Status'][i]=='Y':
        loan['Credit_History'][i]=1

# %%
loan['Credit_History'].isnull().sum()
# Out:
# 49

# %%
x = 'nan'

# %%
x
# Out:
# 'nan'

# %%
x = np.nan

# %%
type(x)
# Out:
# float

# %%
type(loan.iloc[583,10])
# Out:
# numpy.float64

# %%
loan['Credit_History'].fillna(-10,inplace=True)

# %%
loan['Credit_History'].isnull().sum()
# Out:
# 0

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               602 non-null object
# Married              614 non-null object
# Dependents           602 non-null object
# Education            614 non-null object
# Self_Employed        584 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       614 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan['LoanAmount'].fillna(122.7580,inplace=True)

# %%
plt.hist(loan['Loan_Amount_Term'].dropna())
# Out:
# (array([   3.,    6.,    3.,   44.,    4.,    0.,   13.,  512.,    0.,   15.]),
#  array([  12. ,   58.8,  105.6,  152.4,  199.2,  246. ,  292.8,  339.6,
#          386.4,  433.2,  480. ]),
#  <a list of 10 Patch objects>)

# %%
loan['Loan_Amount_Term'].fillna(512,inplace=True)

# %%
Gender=pd.crosstab(loan['Dependents'],loan['Loan_Status'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
sns.countplot(loan['Dependents'].dropna())

# %%
loan['Dependents'].fillna('-10',inplace=True)

# %%
credit = loan['Credit_History']
count=0
for i in range(0,len(credit)):
    if loan['Dependents'][i]=='-10' and loan['Loan_Status'][i]=='N':
        loan['Dependents'][i]='1'
    if loan['Dependents'][i]=='-10' and loan['Loan_Status'][i]=='Y':
        loan['Dependents'][i]='2'
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               602 non-null object
# Married              614 non-null object
# Dependents           614 non-null object
# Education            614 non-null object
# Self_Employed        584 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan[loan['Self_Employed'].isnull()]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 19   LP001041    Male     Yes          0      Graduate           NaN
# 24   LP001052    Male     Yes          1      Graduate           NaN
# 29   LP001087  Female      No          2      Graduate           NaN
# 30   LP001091    Male     Yes          1      Graduate           NaN
# 95   LP001326    Male      No          0      Graduate           NaN
# 107  LP001370    Male      No          0  Not Graduate           NaN
# 111  LP001387  Female     Yes          0      Graduate           NaN
# 114  LP001398    Male      No          0      Graduate           NaN
# 158  LP001546    Male      No          0      Graduate           NaN
# 170  LP001581    Male     Yes          0  Not Graduate           NaN
# 218  LP001732    Male     Yes          2      Graduate           NaN
# 231  LP001768    Male     Yes          0      Graduate           NaN
# ...

# %%
Gender=pd.crosstab(loan['Self_Employed'],loan['Dependents'])
Gender.div(Gender.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True, figsize=(4,4))

# %%
loan['Self_Employed'].fillna('-10',inplace=True)

# %%
credit = loan['Credit_History']
count=0
for i in range(0,len(credit)):
    if loan['Self_Employed'][i]=='-10' and loan['Dependents'][i]=='0':
        loan['Self_Employed'][i]='No'
    if loan['Dependents'][i]=='1' and loan['Self_Employed'][i]=='-10':
        loan['Self_Employed'][i]='Yes'
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
loan[loan['Self_Employed']=='-10']
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 11   LP001027    Male     Yes          2      Graduate           -10
# 29   LP001087  Female      No          2      Graduate           -10
# 218  LP001732    Male     Yes          2      Graduate           -10
# 295  LP001949    Male     Yes         3+      Graduate           -10
# 344  LP002128    Male     Yes          2      Graduate           -10
# 468  LP002502  Female     Yes          2  Not Graduate           -10
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 11              2500             1840.0       109.0             360.0
# 29              3750             2083.0       120.0             360.0
# 218             5000                0.0        72.0             360.0
# 295             4416             1250.0       110.0             360.0
# 344             2583             2330.0       125.0             360.0
# ...

# %%
loan[(loan['Married']=='Yes')&(loan['Dependents']=='2')&(loan['Loan_Status']=='Y')]['Self_Employed'].value_counts()
# Out:
# No     62
# Yes    12
# -10     3
# Name: Self_Employed, dtype: int64

# %%
credit = loan['Credit_History']
count=0
for i in range(0,len(credit)):
    if loan['Self_Employed'][i]=='-10' and loan['Dependents'][i]=='2':
        loan['Self_Employed'][i]='No'
    if loan['Dependents'][i]=='3+' and loan['Self_Employed'][i]=='-10':
        loan['Self_Employed'][i]='Yes'
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               602 non-null object
# Married              614 non-null object
# Dependents           614 non-null object
# Education            614 non-null object
# Self_Employed        614 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan['Gender'].value_counts()
# Out:
# Male      490
# Female    112
# Name: Gender, dtype: int64

# %%
loan['Gender'].fillna('Male',inplace=True)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               614 non-null object
# Married              614 non-null object
# Dependents           614 non-null object
# Education            614 non-null object
# Self_Employed        614 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           614 non-null float64
# Loan_Amount_Term     614 non-null float64
# Credit_History       614 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0     122.758             360.0
# 1             4583             1508.0     128.000             360.0
# 2             3000                0.0      66.000             360.0
# 3             2583             2358.0     120.000             360.0
# 4             6000                0.0     141.000             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan['TotalIncome'] = loan['ApplicantIncome']+loan['CoapplicantIncome']

# %%
#0-10000(low)
#10000-25000(medium)
#25000-50000(high)
#50000-90000(vhigh)
#if accuracy decreases we will cut it

cut_points=[0,10000,25000,50000,90000]
label_names=['lincome','mincome','hincome','vhincome']
loan['TotalIncomeCategories'] = pd.cut(loan['TotalIncome'],cut_points,label_names)

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0     122.758             360.0
# 1             4583             1508.0     128.000             360.0
# 2             3000                0.0      66.000             360.0
# 3             2583             2358.0     120.000             360.0
# 4             6000                0.0     141.000             360.0
#
#    Credit_History Property_Area Loan_Status  TotalIncome TotalIncomeCategories
# 0             1.0         Urban           Y       5849.0            (0, 10000]
# ...

# %%
loan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'TotalIncomeCategories'],
#       dtype='object')

# %%
loan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'TotalIncomeCategories'],
#       dtype='object')

# %%
loan['LoanAmount'] = (loan['LoanAmount'])**(1/3)
replace0={'Loan_Status':{'Y':1,'N':0}}
loan.replace(replace0,inplace=True)

# %%
x = loan[['Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed', 'LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area',
       'TotalIncomeCategories']]

# %%
y = loan['Loan_Status']

# %%
replace1 = {'Gender':{'Male':1,'Female':0}}

# %%
x.replace(replace1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace2 = {'Married':{'Yes':1,'No':0}}

# %%
x.replace(replace2,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace3 = {'Education':{'Graduate':1,'Not Graduate':0}}

# %%
x.replace(replace3,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace4 = {'Self_Employed':{'Yes':1,'No':0}}

# %%
x.replace(replace4,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
x.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  LoanAmount  \
# 0       1        0          0          1              0    4.969926
# 1       1        1          1          1              0    5.039684
# 2       1        1          0          1              1    4.041240
# 3       1        1          0          0              0    4.932424
# 4       1        0          0          1              0    5.204828
#
#    Loan_Amount_Term  Credit_History Property_Area TotalIncomeCategories
# 0             360.0             1.0         Urban            (0, 10000]
# 1             360.0             1.0         Rural            (0, 10000]
# 2             360.0             1.0         Urban            (0, 10000]
# 3             360.0             1.0         Urban            (0, 10000]
# 4             360.0             1.0         Urban            (0, 10000]

# %%
cat_columns = ['Property_Area','TotalIncomeCategories']
dummy_df = pd.get_dummies(x[cat_columns])
x = pd.concat([x,dummy_df],axis=1)
x = x.drop(cat_columns,axis=1)

# %%
x.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  LoanAmount  \
# 0       1        0          0          1              0    4.969926
# 1       1        1          1          1              0    5.039684
# 2       1        1          0          1              1    4.041240
# 3       1        1          0          0              0    4.932424
# 4       1        0          0          1              0    5.204828
#
#    Loan_Amount_Term  Credit_History  Property_Area_Rural  \
# 0             360.0             1.0                    0
# 1             360.0             1.0                    1
# 2             360.0             1.0                    0
# 3             360.0             1.0                    0
# 4             360.0             1.0                    0
#
#    Property_Area_Semiurban  Property_Area_Urban  \
# 0                        0                    1
# 1                        0                    0
# 2                        0                    1
# ...

# %%
replace5 = {'Dependents':{'3+':'3'}}

# %%
x.replace(replace5,inplace=True)

# %%
from sklearn.preprocessing  import StandardScaler
sc_x  =StandardScaler()
x = sc_x.fit_transform(x)
x  =pd.DataFrame(x)

# %%
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.472343 -1.367172 -0.765955  0.528362 -0.411733 -0.169795  0.204264
# 1  0.472343  0.731437  0.222062  0.528362 -0.411733 -0.088142  0.204264
# 2  0.472343  0.731437 -0.765955  0.528362  2.428760 -1.256850  0.204264
# 3  0.472343  0.731437 -0.765955 -1.892641 -0.411733 -0.213693  0.204264
# 4  0.472343 -1.367172 -0.765955  0.528362 -0.411733  0.105164  0.204264
#
#          7         8         9         10        11        12        13  \
# 0  0.345668 -0.641478 -0.782016  1.428147  0.406307 -0.378668 -0.107388
# 1  0.345668  1.558899 -0.782016 -0.700208  0.406307 -0.378668 -0.107388
# 2  0.345668 -0.641478 -0.782016  1.428147  0.406307 -0.378668 -0.107388
# 3  0.345668 -0.641478 -0.782016  1.428147  0.406307 -0.378668 -0.107388
# 4  0.345668 -0.641478 -0.782016  1.428147  0.406307 -0.378668 -0.107388
#
#          14
# 0 -0.070071
# 1 -0.070071
# 2 -0.070071
# 3 -0.070071
# 4 -0.070071

# %%
#from sklearn.cross_validation import train_test_split
#x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
#from sklearn.linear_model import LogisticRegression
#obj = LogisticRegression()
#obj.fit(x_train,y_train)
#y_pred = obj.predict(x_test)

# %%
#from sklearn.metrics import confusion_matrix

# %%
#cm = confusion_matrix(y_test,y_pred)

# %%
#cm

# %%
#from sklearn.tree import DecisionTreeClassifier

# %%
#obj1 = DecisionTreeClassifier(max_depth=3)
#obj1.fit(x_train,y_train)
#y_pred = obj1.predict(x_test)

# %%
88+21+14
# Out:
# 123

# %%
102/123
# Out:
# 0.8292682926829268

# %%
#from sklearn.ensemble import RandomForestClassifier

# %%
#obj2 = RandomForestClassifier(max_depth=3,n_estimators=120)
#obj2.fit(x_train,y_train)
#y_pred = obj2.predict(x_test)

# %%
#cm = confusion_matrix(y_test,y_pred)

# %%
#cm

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0    4.969926             360.0
# 1             4583             1508.0    5.039684             360.0
# 2             3000                0.0    4.041240             360.0
# 3             2583             2358.0    4.932424             360.0
# 4             6000                0.0    5.204828             360.0
#
#    Credit_History Property_Area  Loan_Status  TotalIncome  \
# 0             1.0         Urban            1       5849.0
# ...

# %%
plt.hist(loan['LoanAmount'])
# Out:
# (array([   2.,    9.,   37.,  153.,  259.,   93.,   37.,   11.,    8.,    5.]),
#  array([ 2.08008382,  2.75997944,  3.43987506,  4.11977068,  4.7996663 ,
#          5.47956192,  6.15945754,  6.83935316,  7.51924878,  8.1991444 ,
#          8.87904002]),
#  <a list of 10 Patch objects>)

# %%
#loan['LoanAmount'] = np.sqrt(loan['LoanAmount'])

# %%
#plt.hist(loan["LoanAmount"])

# %%
#plt.hist((loan["LoanAmount"])**(1/3))

# %%
#plt.hist(loan['LoanAmount'])

# %%
loan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0    4.969926             360.0
# 1             4583             1508.0    5.039684             360.0
# 2             3000                0.0    4.041240             360.0
# 3             2583             2358.0    4.932424             360.0
# 4             6000                0.0    5.204828             360.0
#
#    Credit_History Property_Area  Loan_Status  TotalIncome  \
# 0             1.0         Urban            1       5849.0
# ...

# %%
#obj1 = DecisionTreeClassifier(max_depth=3)
#obj1.fit(x_train,y_train)
#y_pred = obj1.predict(x_test)

# %%
#cm=confusion_matrix(y_test,y_pred)

# %%
#cm

# %%
#from xgboost import XGBClassifier

# %%
#obj1 = XGBClassifier(max_depth=2,learning_rate=0.001,random_state=3)
#obj1.fit(x_train,y_train)
#y_pred = obj1.predict(x_test)

# %%
#cm=confusion_matrix(y_test,y_pred)

# %%
#cm

# %%
testLoan = pd.read_csv('testLoan.csv')

# %%
testLoan.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %%
testLoan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
testLoan[testLoan['Gender']=='Female']['Dependents'].fillna("0",inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)

# %%
plt.hist(testLoan['LoanAmount'].dropna())
# Out:
# (array([  46.,  160.,  100.,   37.,    8.,    6.,    2.,    1.,    1.,    1.]),
#  array([  28. ,   80.2,  132.4,  184.6,  236.8,  289. ,  341.2,  393.4,
#          445.6,  497.8,  550. ]),
#  <a list of 10 Patch objects>)

# %%
suum=0
l=testLoan['LoanAmount']
count=0
for i in l:
    if i>=80 and i<135:
        suum=suum+i
        count+=1

# %%
avg = suum/count

# %%
avg
# Out:
# 109.84117647058824

# %%
testLoan['LoanAmount'].fillna(109.84,inplace=True)

# %%
testLoan['Loan_Amount_Term'].fillna(360,inplace=True)

# %%
testLoan.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
testLoan['Gender'].fillna('Male',inplace=True)

# %%
testLoan['Dependents'].fillna('2',inplace=True)

# %%
testLoan['Self_Employed'].fillna('No',inplace=True)

# %%
testLoan['Credit_History'].fillna(1,inplace=True)

# %%
testLoan.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
testLoan['TotalIncome'] = testLoan['ApplicantIncome']+testLoan['CoapplicantIncome']

# %%
plt.hist(testLoan['TotalIncome'])
# Out:
# (array([ 324.,   31.,    6.,    4.,    1.,    0.,    0.,    0.,    0.,    1.]),
#  array([  1760. ,   8836.9,  15913.8,  22990.7,  30067.6,  37144.5,
#          44221.4,  51298.3,  58375.2,  65452.1,  72529. ]),
#  <a list of 10 Patch objects>)

# %%
cut_points=[0,10000,25000,50000,90000]
label_names=['lincome','mincome','hincome','vhincome']
testLoan['TotalIncomeCategories'] = pd.cut(testLoan['TotalIncome'],cut_points,label_names)

# %%
testLoan.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'TotalIncome',
#        'TotalIncomeCategories'],
#       dtype='object')

# %%
X_test = testLoan[['Gender', 'Married', 'Dependents', 'Education',
       'Self_Employed','LoanAmount',
       'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'TotalIncomeCategories']]

# %%
X_test['LoanAmount']=(X_test['LoanAmount']**(1/3))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
replace1 = {'Gender':{'Male':1,'Female':0}}

# %%
X_test.replace(replace1,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace2 = {'Married':{'Yes':1,'No':0}}
X_test.replace(replace2,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace3 = {'Education':{'Graduate':1,'Not Graduate':0}}
X_test.replace(replace3,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
replace4 = {'Self_Employed':{'Yes':1,'No':0}}
X_test.replace(replace4,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
X_test.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  LoanAmount  \
# 0       1        1          0          1              0    4.791420
# 1       1        1          1          1              0    5.013298
# 2       1        1          2          1              0    5.924992
# 3       1        1          2          1              0    4.641589
# 4       1        0          0          0              0    4.272659
#
#    Loan_Amount_Term  Credit_History Property_Area TotalIncomeCategories
# 0             360.0             1.0         Urban            (0, 10000]
# 1             360.0             1.0         Urban            (0, 10000]
# 2             360.0             1.0         Urban            (0, 10000]
# 3             360.0             1.0         Urban            (0, 10000]
# 4             360.0             1.0         Urban            (0, 10000]

# %%
cat_columns = ['Property_Area','TotalIncomeCategories']
dummy_df = pd.get_dummies(X_test[cat_columns])
X_test = pd.concat([X_test,dummy_df],axis=1)
X_test = X_test.drop(cat_columns,axis=1)

# %%
X_test.head()
# Out:
#    Gender  Married Dependents  Education  Self_Employed  LoanAmount  \
# 0       1        1          0          1              0    4.791420
# 1       1        1          1          1              0    5.013298
# 2       1        1          2          1              0    5.924992
# 3       1        1          2          1              0    4.641589
# 4       1        0          0          0              0    4.272659
#
#    Loan_Amount_Term  Credit_History  Property_Area_Rural  \
# 0             360.0             1.0                    0
# 1             360.0             1.0                    0
# 2             360.0             1.0                    0
# 3             360.0             1.0                    0
# 4             360.0             1.0                    0
#
#    Property_Area_Semiurban  Property_Area_Urban  \
# 0                        0                    1
# 1                        0                    1
# 2                        0                    1
# ...

# %%
replace5 = {'Dependents':{'3+':3}}
X_test.replace(replace5,inplace=True)

# %%
sc_x  =StandardScaler()
X_test = sc_x.fit_transform(X_test)
X_test=pd.DataFrame(X_test)

# %%
X_test.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.485479  0.758358 -0.803050  0.544812 -0.334845 -0.360292  0.266022
# 1  0.485479  0.758358  0.129606  0.544812 -0.334845 -0.042207  0.266022
# 2  0.485479  0.758358  1.062263  0.544812 -0.334845  1.264800  0.266022
# 3  0.485479  0.758358  1.062263  0.544812 -0.334845 -0.575090  0.266022
# 4  0.485479 -1.318638 -0.803050 -1.835497 -0.334845 -1.103989  0.266022
#
#          7         8         9         10        11        12        13  \
# 0  0.437674 -0.658478 -0.679817  1.273353  0.303746 -0.281801 -0.090784
# 1  0.437674 -0.658478 -0.679817  1.273353  0.303746 -0.281801 -0.090784
# 2  0.437674 -0.658478 -0.679817  1.273353  0.303746 -0.281801 -0.090784
# 3  0.437674 -0.658478 -0.679817  1.273353  0.303746 -0.281801 -0.090784
# 4  0.437674 -0.658478 -0.679817  1.273353  0.303746 -0.281801 -0.090784
#
#          14
# 0 -0.052271
# 1 -0.052271
# 2 -0.052271
# 3 -0.052271
# 4 -0.052271

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
obj = RandomForestClassifier(max_depth=3,n_estimators=121)
obj.fit(x,y)
y_pred = obj.predict(X_test)

# %%
penalty = {1:3,0:4}

# %%
testLoan['Loan_Status'] = y_pred

# %%
testLoan['Credit_History'].value_counts()
# Out:
# 1.0    308
# 0.0     59
# Name: Credit_History, dtype: int64

# %%
submission = testLoan[['Loan_ID','Loan_Status']]

# %%
submission['Loan_Status'].value_counts()
# Out:
# 1    345
# 0     22
# Name: Loan_Status, dtype: int64

# %%
replace11 = {'Loan_Status':{1:'Y',0:'N'}}

# %%
submission.replace(replace11,inplace=True)
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\pandas\core\generic.py:3855: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   regex=regex)

# %%
submission.to_csv('finalSubmission1')
